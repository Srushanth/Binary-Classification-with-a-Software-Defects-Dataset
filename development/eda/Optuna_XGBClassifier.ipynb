# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv("../../data/train.csv")
df_train.drop(columns=["id"], inplace=True)
df_train["defects"].replace({True: 1, False: 0}, inplace=True)
X = df_train.drop(columns=["defects"])
y = df_train["defects"]

# %%
from sklearn.model_selection import train_test_split

# %%
from xgboost import XGBClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
from functools import partial

# %%
import optuna

# %%
def objective(trial, _X, _y):
    X_train, X_test, y_train, y_test = train_test_split(
        _X, 
        _y, 
        train_size=0.8, 
        random_state=1
    )
    
    param = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-8, 1.0),
        "gamma": trial.suggest_int("gamma", 1, 1000),
        "max_depth": trial.suggest_int("max_depth", 2, 500),
        "min_child_weight": trial.suggest_int("min_child_weight", 2, 1000),
        "max_delta_step": trial.suggest_int("max_delta_step", 2, 100),
        "subsample": trial.suggest_float("subsample", 1e-8, 1.0),
        "lambda": trial.suggest_float("lambda", 1e-8, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 10.0, log=True),
        "max_leaves": trial.suggest_int("max_leaves", 2, 1000),
        "eval_metric": trial.suggest_categorical("eval_metric", ["auc"]), 
        "feature_selector": trial.suggest_categorical("feature_selector", ["cyclic", "shuffle", "random", "greedy", "thrifty"]), 
        "tree_method": trial.suggest_categorical("tree_method", ["exact", "approx", "hist"]), 
        "n_estimators": trial.suggest_int("n_estimators", 2, 256), 
        "n_jobs": -1
    }
    
    xgb = XGBClassifier(**param).fit(X_train, y_train)
    preds = xgb.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = roc_auc_score(y_test, pred_labels)
    
    return accuracy

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2023-10-14 09:33:53,872] A new study created in memory with name: no-name-e1413257-2e18-45c5-8bcd-0c8c1666e9a5

# %%
objective_function = partial(objective, _X=X, _y=y)

# %% [markdown]
#
#         "colsample_bytree": trial.suggest_float("colsample_bytree", 1e-8, 10.0, log=True),
#         "objective": "binary",
#         "tree_method": "hist",
#         "early_stopping_rounds": 256,

# %%
study.optimize(objective_function, n_trials=1000, n_jobs=-1)
# Out:
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:33:55,646] Trial 14 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.684584264301827, 'gamma': 407, 'max_depth': 260, 'min_child_weight': 347, 'max_delta_step': 84, 'subsample': 0.9296489816902732, 'lambda': 2.4562657864343647e-08, 'alpha': 1.932148345031888e-08, 'max_leaves': 853, 'eval_metric': 'auc', 'feature_selector': 'cyclic', 'tree_method': 'approx', 'n_estimators': 11}. Best is trial 14 with value: 0.6491495891216071.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:33:57,786] Trial 16 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.4684759911114059, 'gamma': 503, 'max_depth': 454, 'min_child_weight': 654, 'max_delta_step': 84, 'subsample': 0.47465189368029315, 'lambda': 1.5334157949705334e-06, 'alpha': 5.403160169475661e-07, 'max_leaves': 27, 'eval_metric': 'auc', 'feature_selector': 'thrifty', 'tree_method': 'approx', 'n_estimators': 22}. Best is trial 14 with value: 0.6491495891216071.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:33:57,849] Trial 4 finished with value: 0.7122018604710436 and parameters: {'learning_rate': 0.8843420550075378, 'gamma': 923, 'max_depth': 235, 'min_child_weight': 414, 'max_delta_step': 8, 'subsample': 0.6119607502731474, 'lambda': 3.640178755801845e-05, 'alpha': 0.010500999337901079, 'max_leaves': 107, 'eval_metric': 'auc', 'feature_selector': 'cyclic', 'tree_method': 'hist', 'n_estimators': 95}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:33:57,922] Trial 1 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.7322621774150216, 'gamma': 641, 'max_depth': 317, 'min_child_weight': 832, 'max_delta_step': 57, 'subsample': 0.5142313344709568, 'lambda': 6.751965339326669, 'alpha': 1.604597810397109, 'max_leaves': 278, 'eval_metric': 'auc', 'feature_selector': 'random', 'tree_method': 'approx', 'n_estimators': 38}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:34:00,443] Trial 11 finished with value: 0.5 and parameters: {'learning_rate': 0.32452850439894054, 'gamma': 624, 'max_depth': 54, 'min_child_weight': 872, 'max_delta_step': 52, 'subsample': 0.0067518520081948, 'lambda': 0.0009424459004422281, 'alpha': 1.9840753768806976, 'max_leaves': 584, 'eval_metric': 'auc', 'feature_selector': 'thrifty', 'tree_method': 'hist', 'n_estimators': 170}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:34:01,402] Trial 8 finished with value: 0.5 and parameters: {'learning_rate': 0.05990360801012074, 'gamma': 217, 'max_depth': 157, 'min_child_weight': 354, 'max_delta_step': 42, 'subsample': 0.001507471523148172, 'lambda': 5.827508399615083e-05, 'alpha': 1.638206742860396e-08, 'max_leaves': 120, 'eval_metric': 'auc', 'feature_selector': 'random', 'tree_method': 'exact', 'n_estimators': 246}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:34:01,996] Trial 9 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.4243421399454942, 'gamma': 373, 'max_depth': 92, 'min_child_weight': 684, 'max_delta_step': 80, 'subsample': 0.6675430821574682, 'lambda': 1.1886443438259977e-08, 'alpha': 3.814137040387066e-07, 'max_leaves': 505, 'eval_metric': 'auc', 'feature_selector': 'random', 'tree_method': 'hist', 'n_estimators': 208}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:34:03,026] Trial 3 finished with value: 0.6283118241114154 and parameters: {'learning_rate': 0.27010345727787516, 'gamma': 524, 'max_depth': 81, 'min_child_weight': 932, 'max_delta_step': 18, 'subsample': 0.8222707338736195, 'lambda': 0.0070354548856259285, 'alpha': 2.527798572856707e-06, 'max_leaves': 123, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'exact', 'n_estimators': 71}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:34:03,094] Trial 5 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.23218252833091516, 'gamma': 471, 'max_depth': 91, 'min_child_weight': 95, 'max_delta_step': 58, 'subsample': 0.43820888954189074, 'lambda': 0.0020354418842324345, 'alpha': 1.2281663060913396e-08, 'max_leaves': 136, 'eval_metric': 'auc', 'feature_selector': 'thrifty', 'tree_method': 'hist', 'n_estimators': 234}. Best is trial 4 with value: 0.7122018604710436.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# ...
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:01,139] Trial 989 finished with value: 0.5 and parameters: {'learning_rate': 0.37744263214868, 'gamma': 936, 'max_depth': 368, 'min_child_weight': 169, 'max_delta_step': 9, 'subsample': 0.29116078880732055, 'lambda': 3.830474851877161, 'alpha': 4.024829900705538e-06, 'max_leaves': 641, 'eval_metric': 'auc', 'feature_selector': 'random', 'tree_method': 'approx', 'n_estimators': 137}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:01,527] Trial 991 finished with value: 0.7174354257710056 and parameters: {'learning_rate': 0.9149871874031752, 'gamma': 939, 'max_depth': 458, 'min_child_weight': 610, 'max_delta_step': 23, 'subsample': 0.3589591560207951, 'lambda': 3.300869497946316, 'alpha': 0.11860823412606561, 'max_leaves': 952, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 135}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:01,946] Trial 992 finished with value: 0.6491495891216071 and parameters: {'learning_rate': 0.676312439639076, 'gamma': 882, 'max_depth': 347, 'min_child_weight': 180, 'max_delta_step': 20, 'subsample': 0.5487584570262449, 'lambda': 3.6353049191647075, 'alpha': 0.12727364785006395, 'max_leaves': 660, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 138}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:02,094] Trial 993 finished with value: 0.7174354257710056 and parameters: {'learning_rate': 0.9114928907450632, 'gamma': 941, 'max_depth': 353, 'min_child_weight': 596, 'max_delta_step': 23, 'subsample': 0.2939669812716483, 'lambda': 3.576889187459111, 'alpha': 0.11303609672742965, 'max_leaves': 644, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 139}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:02,476] Trial 995 finished with value: 0.7174354257710056 and parameters: {'learning_rate': 0.9094808834681117, 'gamma': 938, 'max_depth': 351, 'min_child_weight': 173, 'max_delta_step': 20, 'subsample': 0.29690230401025275, 'lambda': 3.715118573416556, 'alpha': 0.11754188872716179, 'max_leaves': 649, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 138}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:02,571] Trial 996 finished with value: 0.7174354257710056 and parameters: {'learning_rate': 0.899131872947387, 'gamma': 943, 'max_depth': 406, 'min_child_weight': 182, 'max_delta_step': 68, 'subsample': 0.1193424314896766, 'lambda': 3.534375698599942, 'alpha': 0.22508637097409906, 'max_leaves': 639, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 134}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:02,827] Trial 997 finished with value: 0.5 and parameters: {'learning_rate': 0.5340931493276602, 'gamma': 647, 'max_depth': 388, 'min_child_weight': 201, 'max_delta_step': 20, 'subsample': 0.12422312066594396, 'lambda': 3.654663429297928, 'alpha': 0.18420130224434714, 'max_leaves': 591, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 137}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:03,423] Trial 994 finished with value: 0.5 and parameters: {'learning_rate': 0.9051165684736885, 'gamma': 931, 'max_depth': 261, 'min_child_weight': 341, 'max_delta_step': 10, 'subsample': 0.027523161213176328, 'lambda': 3.412928785866998, 'alpha': 0.13850318553598595, 'max_leaves': 650, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 167}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:03,661] Trial 998 finished with value: 0.7174354257710056 and parameters: {'learning_rate': 0.9019255253667146, 'gamma': 937, 'max_depth': 396, 'min_child_weight': 388, 'max_delta_step': 100, 'subsample': 0.10942897934620195, 'lambda': 3.473129066434175, 'alpha': 0.18432461668827665, 'max_leaves': 935, 'eval_metric': 'auc', 'feature_selector': 'greedy', 'tree_method': 'approx', 'n_estimators': 137}. Best is trial 711 with value: 0.7193485827129803.
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# [I 2023-10-14 09:44:03,898] Trial 999 finished with value: 0.6283118241114154 and parameters: {'learning_rate': 0.8991310077119193, 'gamma': 945, 'max_depth': 393, 'min_child_weight': 198, 'max_delta_step': 85, 'subsample': 0.7585739401521704, 'lambda': 3.7502778747136647, 'alpha': 0.11958574499121916, 'max_leaves': 759, 'eval_metric': 'auc', 'feature_selector': 'shuffle', 'tree_method': 'approx', 'n_estimators': 136}. Best is trial 711 with value: 0.7193485827129803.

# %%
len(study.trials)
# Out:
# 1000

# %%
study.best_trial
# Out:
# FrozenTrial(number=711, state=TrialState.COMPLETE, values=[0.7193485827129803], datetime_start=datetime.datetime(2023, 10, 14, 9, 40, 55, 689558), datetime_complete=datetime.datetime(2023, 10, 14, 9, 41, 0, 541564), params={'learning_rate': 0.9010174049691081, 'gamma': 849, 'max_depth': 296, 'min_child_weight': 409, 'max_delta_step': 14, 'subsample': 0.0987448171749641, 'lambda': 1.1056176464420966e-07, 'alpha': 3.803997821347391, 'max_leaves': 487, 'eval_metric': 'auc', 'feature_selector': 'shuffle', 'tree_method': 'hist', 'n_estimators': 141}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=1.0, log=False, low=1e-08, step=None), 'gamma': IntDistribution(high=1000, log=False, low=1, step=1), 'max_depth': IntDistribution(high=500, log=False, low=2, step=1), 'min_child_weight': IntDistribution(high=1000, log=False, low=2, step=1), 'max_delta_step': IntDistribution(high=100, log=False, low=2, step=1), 'subsample': FloatDistribution(high=1.0, log=False, low=1e-08, step=None), 'lambda': FloatDistribution(high=10.0, log=True, low=1e-08, step=None), 'alpha': FloatDistribution(high=10.0, log=True, low=1e-08, step=None), 'max_leaves': IntDistribution(high=1000, log=False, low=2, step=1), 'eval_metric': CategoricalDistribution(choices=('auc',)), 'feature_selector': CategoricalDistribution(choices=('cyclic', 'shuffle', 'random', 'greedy', 'thrifty')), 'tree_method': CategoricalDistribution(choices=('exact', 'approx', 'hist')), 'n_estimators': IntDistribution(high=256, log=False, low=2, step=1)}, trial_id=711, value=None)

# %%
study.best_params
# Out:
# {'learning_rate': 0.9010174049691081,
#  'gamma': 849,
#  'max_depth': 296,
#  'min_child_weight': 409,
#  'max_delta_step': 14,
#  'subsample': 0.0987448171749641,
#  'lambda': 1.1056176464420966e-07,
#  'alpha': 3.803997821347391,
#  'max_leaves': 487,
#  'eval_metric': 'auc',
#  'feature_selector': 'shuffle',
#  'tree_method': 'hist',
#  'n_estimators': 141}

# %%
model = XGBClassifier(**study.best_params).fit(X, y)
# Out:
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\core.py:160: UserWarning: [09:44:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "feature_selector" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
df_test = pd.read_csv("../../data/test.csv")
id = df_test["id"]
df_test.drop(columns=["id"], inplace=True)

# %%
result = model.predict_proba(df_test)
# Out:
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\GitHub\Binary-Classification-with-a-Software-Defects-Dataset\venv\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)

# %%
df_submission = pd.DataFrame(data={'id': id ,'defects': result[:, 1]})
df_submission.to_csv('submission.csv', index=False)
